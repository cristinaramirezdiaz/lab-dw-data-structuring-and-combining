# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# %%
# Your code goes here
url1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
df = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)

df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df2.columns = df2.columns.str.lower().str.replace(" ", "_")
df3.columns = df3.columns.str.lower().str.replace(" ", "_")

# %%
df = df.rename(columns={
    "st": "state"
})
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = df2.rename(columns={
    "st": "state"
})
df2
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
df_total = pd.concat([df, df2, df3], axis=0)

df_total
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_total.gender.value_counts()
# Out:
# gender
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: count, dtype: int64

# %%
df_total['gender'].replace({'Male': 'M', 'female': 'M', 'Femal': 'M'}, inplace=True)

df_total['state'].replace({'WA': 'Washington', 'Cali': 'California', 'AZ': 'Arizona'}, inplace=True)

df_total.education.replace({'Bachelors': 'Bachelor'}, inplace=True)

df_total['vehicle_class'].replace({'Sports Car': 'Luxury', 'Luxury Car': 'Luxury', 'Luxury SUV': 'Luxury'}, inplace=True)

df_total['customer_lifetime_value'].replace({'%': ''}, regex=True, inplace=True)
# Out:
# /var/folders/fp/jszwfm992pqbnc932hlygpjr0000gn/T/ipykernel_10231/2838623352.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_total['gender'].replace({'Male': 'M', 'female': 'M', 'Femal': 'M'}, inplace=True)
# /var/folders/fp/jszwfm992pqbnc932hlygpjr0000gn/T/ipykernel_10231/2838623352.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_total.sample(10)
# Out:
#      customer       state gender education customer_lifetime_value   income  \
# 2368      NaN         NaN    NaN       NaN                     NaN      NaN
# 2493  HC16500     Arizona      M    Doctor             8189.967712  72191.0
# 6849  BA87216  California      M   College             20878.41013  50555.0
# 828   JL71713  California      F  Bachelor             6291.655714  89113.0
# 3876  TZ65661  California      F   College             2742.797845  32437.0
# 2646      NaN         NaN    NaN       NaN                     NaN      NaN
# 1520      NaN         NaN    NaN       NaN                     NaN      NaN
# 998   TO60700  Washington      F  Bachelor             7813.411572  25859.0
# 1358      NaN         NaN    NaN       NaN                     NaN      NaN
# 2017  GY88677      Oregon      F  Bachelor             23675.02939  46268.0
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
df_total.customer_lifetime_value = df_total.customer_lifetime_value.astype(float)
df_total.number_of_open_complaints = df_total.number_of_open_complaints.str.split('/').str[1]
df_total.number_of_open_complaints = df_total.number_of_open_complaints.astype(float) # No puedo pasarlo a int porque hay NaN
# Out:
#      customer       state gender             education  \
# 975   YQ15567      Oregon      F              Bachelor
# 227   CD88896      Nevada      M  High School or Below
# 235   DB71122  California      F                Doctor
# 1493  QO16222  California      F               College
# 1456      NaN         NaN    NaN                   NaN
# 2774      NaN         NaN    NaN                   NaN
# 5583  IR50609     Arizona      M              Bachelor
# 790   YG20683  Washington      M               College
# 471   EK87864     Arizona      F               College
# 2231      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 975             903430.580000  18846.0                 115.0
# 227             251459.200000  43860.0                  65.0
# 235             351583.190000  15144.0                  90.0
# 1493              6383.611136      0.0                 196.0
# ...

# %%
df_total.sample(10)

# %%
df.isnull().sum() # isnull() sirve para ver si hay valores faltantes
# Out:
# customer                     2937
# state                        2937
# gender                       3054
# education                    2937
# customer_lifetime_value      2940
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# policy_type                  2937
# vehicle_class                2937
# total_claim_amount           2937
# dtype: int64

# %%
# Identificar las columnas con null o vacías
null_cols = df_total.columns[df_total.isnull().any()]
print(f"Columnas vacías o con valores nulos: {null_cols}")

# Separar las columnas categóricas y numéricas
cat_vars = df_total.select_dtypes(include=['object']).columns
num_vars = df_total.select_dtypes(include=['float64' , 'int64']).columns

# Cambiar los valores nulos con la moda en las variables categóricas

for x in null_cols:
    if x in cat_vars:
        df_total[x].fillna(df_total[x].mode()[0] , inplace = True)

# Lo mismo pero con la media en las numéricas

for x in null_cols:
    if x in num_vars:
        df_total[x].fillna(df_total[x].mean() , inplace = True)
# Out:
# Columnas vacías o con valores nulos: Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')
# /var/folders/fp/jszwfm992pqbnc932hlygpjr0000gn/T/ipykernel_10231/1161589063.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_total[x].fillna(df_total[x].mode()[0] , inplace = True)
# ...

# %%
df_total.sample(10)
# Out:
#      customer       state gender             education  \
# 3325  AC40767  California      F              Bachelor
# 1277  SO57563     Arizona      M               College
# 2511  RU75129  Washington      F  High School or Below
# 2027  GS23406  California      F  High School or Below
# 2117  GX27974  California      F               College
# 278   VM58985  California      M               College
# 1627  AQ70619  California      M  High School or Below
# 4183  CW98743  California      F               College
# 4808  RR47424  California      F  High School or Below
# 3032  FP17993     Arizona      F              Bachelor
#
#       customer_lifetime_value        income  monthly_premium_auto  \
# 3325             1.821964e+05  37828.820291            110.391266
# 1277             7.381914e+03  54878.000000             96.000000
# 2511             2.777342e+03  65431.000000             69.000000
# 2027             2.734328e+03  30916.000000             70.000000
# ...

# %%
df_total.duplicated().sum()
# Out:
# 2939

# %%
df_total.drop_duplicates(inplace=True)

# Reiniciar el índice

df_total.reset_index(drop = True, inplace= True)

# %%
df_total.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here

url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df = pd.read_csv(url)

# %%
df.sample(10)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 1422         1422  YK65946      Oregon              8427.172486      Yes
# 9140         9140  MH14039  California              2592.437797      Yes
# 8609         8609  XV95530      Oregon             11430.588450       No
# 6349         6349  DV24592      Oregon              2472.469209      Yes
# 4727         4727  LZ98529  California             10382.503680       No
# 7087         7087  LY30169  California              3360.269641       No
# 10551       10551  No81415     Arizona              3139.169353       No
# 9652         9652  TB88830  California              8614.686004       No
# 8673         8673  KY57676  California              8400.788878       No
# 3230         3230  AZ68184  Washington              9028.307862       No
#
#        coverage             education effective_to_date employmentstatus  \
# 1422   Extended              Bachelor        2011-02-10         Employed
# ...

# %%
df.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
df.isnull().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# month                            0
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_df = df.pivot_table(index='sales_channel', values=['total_claim_amount'], aggfunc='sum') # el aggfunc sirve para sumar los valores de dos países duplicados
pivot_df
# Out:
#                total_claim_amount
# sales_channel
# Agent                1.810227e+06
# Branch               1.301204e+06
# Call Center          9.266008e+05
# Web                  7.066000e+05

# %%
sales_total = pivot_df.round(2)
sales_total
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
average_lifetime = df.pivot_table(index='gender', columns = 'education', values=['customer_lifetime_value'], aggfunc='mean') # el aggfunc sirve para sumar los valores de dos países duplicados
average_lifetime = average_lifetime.round(2)
average_lifetime
# Out:
#           customer_lifetime_value                                         \
# education                Bachelor  College   Doctor High School or Below
# gender
# F                         7874.27  7748.82  7328.51              8675.22
# M                         7703.60  8052.46  7415.33              8149.69
#
#
# education   Master
# gender
# F          8157.05
# M          8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
